# %%
import sys
sys.path.insert(0,'/Users/flatironschool/Final-Project/final-project')

from MakingInvoiceDataframes import *

# %%
import pandas as pd

pdf_df = pd.DataFrame(make_dicts(all_files))

# %%
pdf_df
# Out:
#                                                 Artist  \
# 0    [b'Michiyo Ihara', b'Jessica McCambly', b'Jess...
# 1                 [b'Charles Clary', b'Charles Clary']
# 2    [b'Laura Moriarty', b'Laura Moriarty', b'Eve S...
# 3    [b'Lorraine Glessner', b'David Licata', b'Davi...
# 4                       [b'Carlos Gamez de Francisco']
# 5                              [b'Jackie Battenfield']
# 6                                                   []
# 7                                     [b'Jill Parisi']
# 8                                  [b'Margaret Neill']
# 9                                   [b'Melanie Parke']
# 10                                                  []
# 11                               [b'David Konigsberg']
# 12                    [b'Mary Judge', b'Eve Stockton']
# 13                 [b'Eve Stockton', b'David Collins']
# 14                                   [b'Eve Stockton']
# 15                                   [b'Eve Stockton']
# ...

# %%
pdf_df.columns
# Out:
# Index(['Artist', 'Date Created by Artist', 'Date Sold', 'Dimensions',
#        'INVOICE ID', 'Medium', 'Titles'],
#       dtype='object')

# %%
# Saving original dataframe just in case (not cleaned or anything yet)

pdf_df.to_csv('pdf_df')

# %% [markdown]
# ## .doc Invoices

# %%
# Trying stuff out with Word invoices

import subprocess

subprocess.run("/Applications/LibreOffice.app/Contents/MacOS/soffice --headless --convert-to txt:Text /Users/flatironschool/Final-Project/Invoices_WordDocs/test", shell=True, check=True)
# Out:
# CompletedProcess(args='/Applications/LibreOffice.app/Contents/MacOS/soffice --headless --convert-to txt:Text /Users/flatironschool/Final-Project/Invoices_WordDocs/test', returncode=0)

# %%
# Removing spaces from file names

import os

path =  '/Users/flatironschool/Final-Project/Invoices_WordDocs/test/'

filenames = os.listdir('/Users/flatironschool/Final-Project/Invoices_WordDocs/test/')

for filename in filenames:
    os.rename(os.path.join(path + filename), os.path.join(path + filename.replace(" ", "-")))

# %%
import os 

for file in os.listdir('/Users/flatironschool/Final-Project/Invoices_WordDocs/test'):

    os.system(f'/Applications/LibreOffice.app/Contents/MacOS/soffice --headless --convert-to txt:Text /Users/flatironschool/Final-Project/Invoices_WordDocs/test/{file} --outdir /Users/flatironschool/Final-Project/Invoices_WordDocs/test_output')
