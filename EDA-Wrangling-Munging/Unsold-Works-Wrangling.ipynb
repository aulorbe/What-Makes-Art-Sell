# %% [markdown]
# # Turning Invoices for Unsold Works into .txt Files

# %%
# Turn Word docs into .txt files

import os

for file in os.listdir('/Users/flatironschool/Final-Project/Invoices_NOTSOLD/WordDocs'):

    os.system(f'/Applications/LibreOffice.app/Contents/MacOS/soffice --headless --convert-to txt:Text /Users/flatironschool/Final-Project/Invoices_NOTSOLD/WordDocs/{file} --outdir /Users/flatironschool/Final-Project/Invoices_NOTSOLD/WordDocsToText')

# %%
# Turning PDFs into .txt files

import os 
file_names = []

for file in os.listdir('/Users/flatironschool/Final-Project/Invoices_NOTSOLD/PDFs'):
    file_names.append(file)

for file in file_names:
    os.system(f'pdf2txt.py -o {file}.txt /Users/flatironschool/Final-Project/Invoices_NOTSOLD/PDFs/{file}')

# %% [markdown]
# # Getting File Names for Unsold Works

# %%
unsold_file_names = []

for folder in os.listdir('/Users/flatironschool/Final-Project/Images_NOTSOLD'):
    
    for file in os.listdir(f'/Users/flatironschool/Final-Project/Images_NOTSOLD/{folder}'): 
        unsold_file_names.append(file)

# %%
unsold_file_names # 196 image files
# Out:
# ['UNSOLD-GlessnSentientMagnoliaTheGreatSaltLake3_30x40x1_5.jpg',
#  'UNSOLD-GlessnTheSentientMagnoliaGreatSaltLake4_30x40x1_5.jpg',
#  'UNSOLD-GlessnBetweenSleepAndDreams1_24x24x1.jpg',
#  'UNSOLD-GlessnTheSentientMagnoliaGreatSaltLake2_30x40x1_5.jpg',
#  'UNSOLD-GlessnFlirtatiousSuperficiality36x72.jpeg',
#  'UNSOLD-GlessnBurnBabyBurn48x48x1_5.jpg',
#  'UNSOLD-GrossVSH5OilonLinen64x32 copy.JPG',
#  'UNSOLD-GrossVSH6_2014OilOnLinen64x32 copy.JPG',
#  'UNSOLD-GrossStudyVSH3_24x14 copy.jpg',
#  'UNSOLD-GrossStudyVSH20_22_5x13_5 copy.jpg',
#  'UNSOLD-GouacheGroup copy.jpg',
#  'UNSOLD-GrossStudyVSH10_22_5x13_5 copy.jpg',
#  'UNSOLD-GrossStudyVSH12_22_5x13_5 copy.jpg',
#  'UNSOLD-GrossStudyVSH21_22_5x13_5 copy.jpg',
#  'UNSOLD-GrossStudyVSH5_24x14 copy.jpeg',
#  'UNSOLD-GrossVSH4_2014_64x32 copy.jpg',
#  'UNSOLD-WrightShieldDoily2010PaperMetal21x21.jpg',
#  'UNSOLD-WrightArtemisHide2010PaperRubberMetal25x21Framed.jpg',
#  'UNSOLD-WrightOffSwitchDoily15x15.jpg',
#  'UNSOLD-outside the house.jpg',
#  'UNSOLD-WrightAreola15x15.jpg',
#  'UNSOLD-WrightUntitled12x12.jpg',
#  'UNSOLD-WrightMirrorStageRedux1_2012AcrylicCanvas48x36.jpg',
#  'UNSOLD-WrightGreyOnYellow2OilCanvas10x8 copy.jpg',
#  'UNSOLD-Untitled 2.jpg',
#  'UNSOLD-inside the house.jpg',
#  'UNSOLD-WrightGreyOnYellow 1OilCanvas10x8 copy.jpg',
#  'UNSOLD-WrightYellowOn BlackOilCAnvas10x8 copy.jpg',
#  'UNSOLD-VuTheNewWorld_Opening2_2013OilDibond30x80.jpg',
#  'UNSOLD-VuTheNew World_Portal_Opening2_2013OilDibond48Diameter.jpg',
#  'UNSOLD-VuTransientsBrothers2004CharcoalPastelPaper40x26.jpg',
#  'UNSOLD-VuTransientsMotherandDaughter2004CharcoalPastelPaper40x26.jpg',
#  'UNSOLD-SerpicTheSovereignOrder2011OilCanvas28x22$3200.jpg',
#  'UNSOLD-SerpicAlienLifeAsSeenOnTV2011OilCanvas28x22$3200.jpg',
#  'UNSOLD-JFintz_3_4_5_Turnabout#1AcrylicCanvas54x60in_2007.jpg',
#  'UNSOLD-Fintzj_AlignAllyHiRes.jpg',
#  'UNSOLD-GrossmDoubleLuftmensch3_2014EncuasticPanel8x10.jpg',
#  'UNSOLD-GrossmFeelinIt39x45 copy.jpg',
#  'UNSOLD-GrossmGospelSinger2014OilCanvas14x14.jpg',
#  'UNSOLD-GrossmSmallLuftmentsh7_2014EncausticPanel7_5x10.jpg',
#  'UNSOLD-GrossmTheEastDeck39x45 copy.jpg',
#  'UNSOLD-GrossmSmallModernMan1_2014EncausticPanel10x7_5.jpg',
#  'UNSOLD-StOnge_SlugJar.jpg',
#  'UNSOLD-StOnge_Watermelo.jpeg',
#  'UNSOLD-stonge_waspnest.jpg',
#  'UNSOLD-stonge_birdinhands-1.jpg',
#  'UNSOLD-neg095.tiff',
#  'UNSOLD-neg096.tiff',
#  'UNSOLD-StOnge_BabyDuck.jpeg',
#  'UNSOLD-stonge_girlwatchingfish.jpg',
#  'UNSOLD-stonge_froginjar.jpg',
#  'UNSOLD-stonge_seaweedjar-1.jpg',
#  'UNSOLD-KozolAtlas44x48.jpg',
#  'UNSOLD-KozolWeepingCherryII_2013OilCanvas44x48.jpg',
#  'UNSOLD-KozolCarya2014OilCanvas48x44.jpg',
#  'UNSOLD-KozolCanary2009OilCanvasPanel36x40.jpg',
#  'UNSOLD-HomerSewingAtNight48x40.jpg',
#  'UNSOLD-HomerHereAndThere49x28.jpg',
#  'UNSOLD-SpergeAnchor1_1_1_2011Monotype10x10.JPG',
#  'UNSOLD-SpergeSantaMariaNovella2_30x32.JPG',
#  'UNSOLD-SpergeSanMiniato1_30x32.jpg',
#  'UNSOLD-SpergeWrap36x40.jpg',
#  'UNSOLD-SpergeAnchor2_1_1_2011Monotype10x10.JPG',
#  'UNSOLD-SpergeSantaMariaNovella1_11x14.jpg',
#  'UNSOLD-SpergeValentine10x10.JPG',
#  'UNSOLD-SpergInTheAir_12_11x14.jpg',
#  'UNSOLD-SpergeSantoSpirito2_30x32.jpg',
#  'UNSOLD-WalshSUIT22x24.jpg',
#  'UNSOLD-WalshSUIT22x249install.JPG',
#  'UNSOLD-WalshBOX24x21.jpg',
#  'UNSOLD-IMG_4130.JPG',
#  'UNSOLD-WalshWINK13x15x3_5.jpg',
#  'UNSOLD-WalshPUNCH36x48.jpg',
#  'UNSOLD-PollacSeaOfTranquility2011OilCanvas36x48.jpg',
#  'UNSOLD-PollacNaturalLaw2010OilCanvas34x50.jpg',
#  'UNSOLD-PollacSplitTreeOilLinen20x30.jpg',
#  'UNSOLD-SmithAsianTouch09_30x40OilCanvas$3300HighRes.jpg',
#  'UNSOLD-SmithThePianoRoom30x40OilCanvas$3400HighResImage.jpg',
#  'UNSOLD-PaulseFloodedBandstand38x20HR.jpg',
#  'UNSOLD-PaulseLastManStandingInTheLastBastion37_75x41HR.JPG',
#  'UNSOLD-PaulseLastBastion4_55x64.jpg',
#  'UNSOLD-RamireMorningHikeUpTheCanyon54x35.jpg',
#  'UNSOLD-RamireWinterSurf30x60HR.jpg',
#  'UNSOLD-RamireDuskAtTheEdgeOfTheWoods48x54.jpg',
#  'UNSOLD-SwansoNeptuneRising66x60HR copy.jpg',
#  'UNSOLD-SwansoBarcelonaNight66x60HR copy.jpg',
#  'UNSOLD-SwansoHercules66x60HR.jpg',
#  'UNSOLD-SwansoBlueBull60x60HR.jpg',
#  'UNSOLD-SwansoCreation66x60HR.jpg',
#  'UNSOLD-CRinklPlasmaticSpree2006OilAcrylicDibondAluminum36x30.jpg',
#  'UNSOLD-RinklinVestige2009FlasheDuralar24x20.jpeg',
#  'UNSOLD-RinklinPuffs2009FlasheDuraLar17x14.jpeg',
#  'UNSOLD-RinklinBoundForGlory2009FlasheDuralar17x14.jpeg',
#  'UNSOLD-RinklinPlacid2009FlasheDuraLar17x14.jpeg',
#  'UNSOLD-SharreLovesong36x36.jpg',
#  'UNSOLD-SharreSmooth8x8x1_25.jpg',
#  'UNSOLD-SharreYellow19x19.jpg',
#  'UNSOLD-SharreDestiny36x36HR.jpg',
#  'UNSOLD-SharreLoveAndAffection36x36.jpg',
#  'UNSOLD-JustisUntitledBaroque14_2011ReliefMonoprintEmbossingRivesBFKpaper42_5x31_75.jpg',
#  'UNSOLD-JustisUntitledBaroque12_2011ReliefMonoprintEmbossingRivesBFKpaper42_5x31_75.jpg',
#  'UNSOLD-JustisUntitledBaroque4_2011ReliefMonoprintEmbossingRivesBFKPaper42_5x31_75.jpg',
#  'UNSOLD-TaliaProposal2014OilCanvas28x24.jpg',
#  'UNSOLD-TaliaArrangementInPinkAndGreen2011OilLinen36x40.jpg',
#  'UNSOLD-TaliaSandy2013OilCanvas24x24.jpg',
#  'UNSOLD-TaliaLaurinburg2014OilCanvas28x24.jpg',
#  'UNSOLD-TaliaWinter2014OilCanvas30x45.jpg',
#  'UNSOLD-SteigShamokin19x15.jpg',
#  'UNSOLD-SteigTunnel26_5x22_5.jpg',
#  'UNSOLD-SteigerAerialSurvey1_20x30.jpg',
#  'UNSOLD-SteigKillVanKull1993Ed12_15EtchingAquatint19x15.jpg',
#  'UNSOLD-SteigerTrestleCrossing20x30.jpg',
#  'UNSOLD-SteigMonongahela19x15.jpg',
#  'UNSOLD-SteigTransmissionTower1995Ed14_30ColorLithographPaper27x22_5.jpg',
#  'UNSOLD-SteigSemaphoreCollage.jpg',
#  'UNSOLD-SteigWonderwheel2002Ed15_30EtchingAquatintPaper26_5x22_5.jpg',
#  'UNSOLD-MaffiaCelestialSea1_35x49.JPG',
#  'UNSOLD-MaffiaSalt1_27x35.JPG',
#  'UNSOLD-MaffiaCelestialSea2_35x28.JPG',
#  'UNSOLD-MaffiaMeditations1_32x45.JPG',
#  'UNSOLD-KantroOreithya36x60.jpg',
#  'UNSOLD-KantroRaveling36x36.jpg',
#  'UNSOLD-KantroIrrationalExuberance_36x60.jpg',
#  'UNSOLD-KantroCitrus20x20.jpg',
#  'UNSOLD-KantroMyriadRavines36x60.jpg',
#  'UNSOLD-FrankSilverSilky2011SilkFabricSatinRibbonMattBoardVinylAcrylicGessoCotton24x20.jpg',
#  'UNSOLD-FrankCosmicCremeII_2013WoolFeltVinylAcrylicPaintGessoPanel24x20.jpg',
#  'UNSOLD-FrankFormYou2013WoolFeltVinylAcrylicPaintGessoPanel22x22.jpg',
#  'UNSOLD-FrankIndianSilky2010IndianSilkFabricSatinRibbonMattBoardVinylAcrylicGessoCotton18x14.jpg',
#  'UNSOLD-FrankFeltNo1WithVariousColoredCircles2012WoolFeltVinylAcrylicGessoPanel24x16.jpg',
#  'UNSOLD-FrankFirstFeltNecklace2012WoolFeltVinylAcrylicGessoPanel20x16.jpg',
#  'UNSOLD-NeillDEW20x20.jpg',
#  'UNSOLD-NeillCIRRUS67x43HR.jpg',
#  'UNSOLD-NeillREPOSSESS29x26.jpg',
#  'UNSOLD-NeillADVANCE36x36.jpeg',
#  'UNSOLD-NeillRECESS36x48.jpeg',
#  'UNSOLD-NeillINTERIM36x48.jpg',
#  'UNSOLD-NeillConduit46_5x42HR.jpg',
#  'UNSOLD-NeillCUE60x60.jpg',
#  'UNSOLD-NeillSnap24x24.jpg',
#  'UNSOLD-NeillTempo48x36HR.jpg',
#  'UNSOLD-NeillRECRUIT56x72.jpg',
#  'UNSOLD-IMG_4128.JPG',
#  'UNSOLD-GrassiHouseFloatNo2_38_5x50_5.jpg',
#  'UNSOLD-GrassiFreeze22x30.jpg',
#  'UNSOLD-IMG_4110 copy.jpg',
#  'UNSOLD-GrassiBackUp54x44HR.jpg',
#  'UNSOLD-IMG_4126.JPG',
#  'UNSOLD-IMG_4132.JPG',
#  'UNSOLD-ChambeGoneGirls36x36.jpg',
#  'UNSOLD-ChambeMySummerVacation36x36.jpg',
#  'UNSOLD-SearsSongbirds10_25x19_75.jpg',
#  'UNSOLD-SearsSwoop_26x20.jpg',
#  'UNSOLD-S1_SwimmersPrintFlat.jpg',
#  'UNSOLD-N1_SongbirdsPrintflat.jpg',
#  'UNSOLD-N3_Ride_BobcatsPrintflat copy.jpg',
#  'UNSOLD-N4_SwallowsPrintflat copy.jpg',
#  'UNSOLD-N5_HeronsPrintflat copy.jpg',
#  'UNSOLD-SearsCircus36x26.jpg',
#  'UNSOLD-S4_ElephantprintFlat copy.jpg',
#  'UNSOLD-S2_SwoopPrintflat copy.jpg',
#  'UNSOLD-SearsGold30x19.jpg',
#  'UNSOLD-IMG_2135.jpg',
#  'UNSOLD-IMG_2134.jpg',
#  'UNSOLD-S6_Owlsprintflat copy.jpg',
#  'UNSOLD-SearsSwimmers_26x20.jpg',
#  'UNSOLD-N2_Undertow_BearsPrintflat copy.jpg',
#  'UNSOLD-SearsHawks15x25.jpg',
#  'UNSOLD-IMG_2140.jpg',
#  'UNSOLD-SearsOwls15x29_38.jpg',
#  'UNSOLD-S5_Hawksprintflat copy.jpg',
#  'UNSOLD-SvalbArchitrave1_2013OilWaxIndustrialFelt72x36.jpg',
#  'UNSOLD-SvalbBrunswick_E_2013OilWaxIndustrialFelt14x14.jpg',
#  'UNSOLD-TilestCloserThanTheyAppear60x72HR.jpg',
#  'UNSOLD-TilestOrnamentofClearRealization60x48HR.jpg',
#  'UNSOLD-TilestoEverything5_30x22.jpg',
#  'UNSOLD-TilestLiberationAnxiety60x48.jpg',
#  'UNSOLD-TilestoInfatuationEngine72x60.jpg',
#  'UNSOLD-TilestoFieldGuide6_30x22.jpg',
#  'UNSOLD-BellaPhantomLimbMarkingWonderland_67x53HR.jpg',
#  'UNSOLD-BellaPhantomLimbGuilt2_60x44HR.jpg',
#  'UNSOLD-BellaPhantomLimbCheshireGrin1_41_5x48HR.jpg',
#  'UNSOLD-BellaPhantomLimbGuilt1_60x41HR.jpg',
#  'UNSOLD-BellaPhantomLimbCheshireGrin2_41_5x48HR.jpg',
#  'UNSOLD-CollinBlacktop32x44.jpg',
#  'UNSOLD-CollinWhatWeBringWithUs44x44.jpg',
#  'UNSOLD-CollinUntitled20x40.jpg',
#  'UNSOLD-CollinOrion44x44HR.jpg',
#  'UNSOLD-CollinsCanards38x32.jpg',
#  'UNSOLD-CollinNotchDrawLoose2013AcrylicLinen60x60HR_ColorCode.tiff',
#  'UNSOLD-GreenbJaqueton1742_2010ArchivalPigmentPrint50_4x41Edition5.jpg',
#  'UNSOLD-GreenbRomero_1177_2010ArchivalPigmentPrint26_7x20Edition5.jpg',
#  'UNSOLD-GreenbSerpa0601_2010ArchivalPigmentPrint20_5x16UniquePrint.jpg',
#  'UNSOLD-GreenbCasey_01_2010ArchivalPigmentPrint42x42Edition10.jpg',
#  'UNSOLD-KnutsoBipolarOvoidCoilsIIOilOnCanvas48x48inches2011$5000-1.jpg',
#  'UNSOLD-KnutsoTripolarTransparentStarCoilsIIOilOnCanvas28x28inches2011$3,000.jpg']
